# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\marwa\Downloads\sm sales\supermarket_sales - Sheet1.csv")

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
data.sample(15)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 902  595-94-9924      A     Yangon        Member  Female
# 306  286-01-5402      A     Yangon        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
# 484  493-65-6248      C  Naypyitaw        Member  Female
# 451  744-09-5786      B   Mandalay        Normal    Male
# 62   347-34-2234      B   Mandalay        Member  Female
# 775  120-54-2248      B   Mandalay        Normal  Female
# 855  895-03-6665      B   Mandalay        Normal  Female
# 161  275-28-0149      A     Yangon        Normal    Male
# 24   549-59-1358      A     Yangon        Member    Male
# 532  857-67-9057      B   Mandalay        Normal    Male
# 817  832-51-6761      A     Yangon        Normal    Male
# 353  565-67-6697      B   Mandalay        Member    Male
# 819  190-59-3964      B   Mandalay        Member    Male
# 204  394-43-4238      B   Mandalay        Member    Male
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.countplot(x= 'Product line',data = data)
# Out:
# <AxesSubplot: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Product line',hue='Gender',data=data)
# Out:
# <AxesSubplot: xlabel='Product line', ylabel='count'>

# %%
sns.pairplot(data)

# %%
sns.barplot(x="Branch",y="Total" , data = data)
# Out:
# <AxesSubplot: xlabel='Branch', ylabel='Total'>

# %%
sns.barplot(x="Customer type",y="Total" , data = data)
# Out:
# <AxesSubplot: xlabel='Customer type', ylabel='Total'>

# %%
sns.barplot(x="Customer type",y="Rating" , data = data)
# Out:
# <AxesSubplot: xlabel='Customer type', ylabel='Rating'>

# %%
sns.boxplot(data["Rating"])
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize = (12,6))
data['Product line'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize = (12,6))
sns.barplot(x="Product line",y="Total" , data = data , hue = "Gender")
# Out:
# <AxesSubplot: xlabel='Product line', ylabel='Total'>

# %%
data_data = data[['Unit price', 'Quantity', 'Total', 'cogs', 'gross income',
       'Rating']]

plt.figure(figsize=(12,8))
sns.heatmap(data_data.corr(), annot = True, cmap = 'viridis')
plt.show()

# %%
data['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
data['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
data['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
data['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
Branches = data.groupby('Branch')

# %%
plt.figure(figsize=(15,5))
colors = ['black', 'yellow', 'green']
explode = (0.1, 0, 0)
dfp =data['Payment'].unique().tolist()
dfd= data['Payment'].value_counts()
plt.pie(dfd,explode=explode,labels=dfp, autopct= '%2.1f%%', colors=colors)
plt.title('Pie Chart comparing Payment Methods being used')
plt.savefig('Super2.png')
